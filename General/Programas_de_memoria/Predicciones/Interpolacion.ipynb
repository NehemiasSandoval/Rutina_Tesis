# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import  matplotlib.pyplot as plt
from scipy import stats
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix
from sklearn.linear_model import LinearRegression
import pandas as pd
from scipy import stats
from sklearn.tree import DecisionTreeRegressor
from sklearn.preprocessing import PolynomialFeatures
from sklearn import datasets, linear_model
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
import os
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Data_Correlacion

# %%
path =  r"/mnt/c/Users/gemel/OneDrive - Universidad Técnica Federico Santa María/General - Refinamiento Adaptativo/Programas de memoria/Data_correlacion"
import os
for h in reversed(os.listdir(path)):
 os.chdir(r"/mnt/c/Users/gemel/OneDrive - Universidad Técnica Federico Santa María/General - Refinamiento Adaptativo/Programas de memoria/Data_correlacion")
 import os
 if str(h) != "Evaluacion_modelos" and str(h) != "Graficos":
  hh = str(h)
  name_1 = (hh.split(sep='_'))[0]
  dens_1 = (hh.split(sep='_'))[1]
  df_1 = pd.read_csv(hh)
  for p in (os.listdir(path)):
     if str(p) != "Evaluacion_modelos" and str(p) != "Graficos":
      pp = str(p)
      name_2 = (pp.split(sep='_'))[0]
      dens_2 = (pp.split(sep='_'))[1]
      lista_interp = []
      path_final = r"/mnt/c/Users/gemel/OneDrive - Universidad Técnica Federico Santa María/General - Refinamiento Adaptativo/Programas de memoria/Data_correlacion/Evaluacion_modelos/interpolacion_misma_malla"
      for Nombres_archivos_interpolacion in os.listdir(path_final):
        Malla_gruesa , Malla_fina = (Nombres_archivos_interpolacion.split(sep='-'))[1] , (Nombres_archivos_interpolacion.split(sep='-'))[2]
        dens_malla_fina , dens_malla_gruesa , Nombre_mol = (Malla_fina.split(sep='_')[1]), (Malla_gruesa.split(sep='_')[1]) , (Malla_gruesa.split(sep='_')[0])
        a = [Nombre_mol , dens_malla_gruesa, dens_malla_fina]
        lista_interp.append(a)
      Lista_a_comprobar = [name_2,dens_1 , dens_2]
      print(name_1, Lista_a_comprobar)
      if name_2 == name_1 and dens_1 < dens_2 and Lista_a_comprobar not in lista_interp:
        Checkeo = False
        for u in os.listdir(path):
         if str(u) != "Evaluacion_modelos" and str(u) != "Graficos":
          uu = str(u)
          name_3 = (uu.split(sep='_'))[0]
          dens_3 = (uu.split(sep='_'))[1]
          if name_3 == name_2 and dens_3< dens_2 and dens_3 > dens_1:
            Checkeo = True
        if Checkeo:
            df_1 = pd.read_csv(hh)
            df_2 = pd.read_csv(pp)
            frames = [df_1, df_2]
            df = pd.concat(frames , ignore_index=True,axis=0)
            df=(df-df.min())/(df.max()-df.min())
            Puntuación_modelos = np.zeros([15,1])
            depth = 40
            Percent = 90
            TR_size = 0.95
            percentiles = stats.scoreatpercentile(df['E_u'] , Percent)
            X = df.iloc[:,0:11]
            Y = df['E_u']
            Refinamiento_test =np.zeros([len(df['E_u']),1])
            for j in range(len(df['E_u'])):
              if (df['E_u'])[j] >= percentiles:
                Refinamiento_test[j] = True
              else:
                Refinamiento_test[j] = False
            df['Si/No'] = Refinamiento_test
            Y_df = df['Si/No']
            X_train , X_test, Y_train , Y_test = train_test_split(X,Y_df,train_size = TR_size , random_state = 0)
            Tree = DecisionTreeClassifier(max_depth = depth)
            Arbol_Error = Tree.fit(X_train , Y_train)
            Y_pred = Arbol_Error.predict(X)
            adr = DecisionTreeRegressor(max_depth = 5)
            adr.fit(X_train ,Y_train)
            y = adr.predict(X_test)
            Refinamiento_pred_a= np.zeros([len(df['E_u']),1])
            for j in range(len(df['E_u'])):
              X_eval = np.array(df.iloc[j,0:11])
              pred =adr.predict([X_eval])
              if pred >= percentiles:
               Refinamiento_pred_a[j] = True
              else:
               Refinamiento_pred_a[j] = False
            X_train , X_test, Y_train , Y_test = train_test_split(X,df['E_u'],train_size = TR_size , random_state = 0)
            multiple_linear = LinearRegression()
            multiple_linear.fit(X_train, Y_train)
            multiple_linear.score(X_test, Y_test)
            Refinamiento_pred= np.zeros([len(df['E_u']),1])
            for j in range(len(df['E_u'])):
              X_eval = np.array(df.iloc[j,0:11])
              pred =multiple_linear.predict([X_eval])
              if pred >= percentiles:
               Refinamiento_pred[j] = True
              else:
               Refinamiento_pred[j] = False
            degreed = 4
            poly_reg = PolynomialFeatures(degree = degreed)
            X_train_poli = poly_reg.fit_transform(X_train)
            X_test_poli = poly_reg.fit_transform(X_test)
            pr = linear_model.LinearRegression()
            pr.fit(X_train_poli , Y_train)
            Y_pred_pr = pr.predict(X_test_poli)
            Refinamiento_pred= np.zeros([len(df['E_u']),1])
            for j in range(len(df['E_u'])):
              X_eval = (np.array(df.iloc[j,0:11])).reshape(1,-1)
              X_eval = poly_reg.fit_transform(X_eval)
              pred =pr.predict(X_eval)
            RFR = RandomForestRegressor(n_estimators=200 , max_depth = 8)
            RFR.fit(X_train , Y_train)
            Refinamiento_pred= np.zeros([len(df['E_u']),1])
            for j in range(len(df['E_u'])):
              X_eval = np.array(df.iloc[j,0:11]).reshape(1,-1)
              pred = RFR.predict(X_eval)
            df = pd.DataFrame(Puntuación_modelos , columns = [pp])
            df.rename(index={0:'Glob Class Tree',1:'Ref Class Tree',2:'No Ref Class Tree', 3:'Glob Reg Tree',4:'Ref Reg Tree',5:'No Ref Reg Tree', 6:'Glob Lin Reg',7:'Ref Lin Reg',8:'No Ref Lin Reg', 9:'Glob Pol Reg',10:'Ref Pol Reg',11:'No Ref Pol Reg', 12:'Glob RFR',13:'Ref RFR',14:'No Ref RFR'}, inplace=True)
            for u in os.listdir(path):
             if str(u) != "Evaluacion_modelos" and str(u) != "Graficos":
              uu = str(u)
              name_3 = (uu.split(sep='_'))[0]
              dens_3 = (uu.split(sep='_'))[1]
              if name_3 == name_2 and dens_3< dens_2 and dens_3 > dens_1:
                df_3 = pd.read_csv(uu)
                df_3=(df_3-df_3.min())/(df_3.max()-df_3.min())
                percentiles_2 = stats.scoreatpercentile(df_3['E_u'] , Percent)
                Puntuación_modelos_2 = np.zeros([15,1])
                percentiles_2 = stats.scoreatpercentile(df_3['E_u'] , Percent)
                Puntuación_modelos_2 = np.zeros([15,1])
                X_2 = df_3.iloc[:,0:11]
                Y_2 = df_3['E_u']
                Refinamiento_pred_2= np.zeros([len(df_3['E_u']),1])
                for j in range(len(df_3['E_u'])):
                  X_eval = np.array(df_3.iloc[j,0:11])
                  pred =multiple_linear.predict([X_eval])
                  if pred >= percentiles_2:
                    Refinamiento_pred_2[j] = True
                  else:
                    Refinamiento_pred_2[j] = False
                Refinamiento_test_2 =np.zeros([len(df_3['E_u']),1])
                for j in range(len(df_3['E_u'])):
                  if (df_3['E_u'])[j] >= percentiles_2:
                    Refinamiento_test_2[j] = True
                  else:
                    Refinamiento_test_2[j] = False
                Matriz_confusion_lin_2 = confusion_matrix(Refinamiento_test_2, Refinamiento_pred_2)
                Presicion_global_lin_2 = np.sum(Matriz_confusion_lin_2.diagonal())/np.sum(Matriz_confusion_lin_2)
                Presicion_SI_lin_2 = (Matriz_confusion_lin_2[1,1])/sum(Matriz_confusion_lin_2[1,])
                Presicion_NO_lin_2 = (Matriz_confusion_lin_2[0,0])/sum(Matriz_confusion_lin_2[0,])
                Puntuación_modelos_2[6,0] = Presicion_global_lin_2
                Puntuación_modelos_2[7,0] = Presicion_SI_lin_2
                Puntuación_modelos_2[8,0] = Presicion_NO_lin_2
                for j in range(len(df_3['E_u'])):
                  X_eval = (np.array(df_3.iloc[j,0:11])).reshape(1,-1)
                  X_eval = poly_reg.fit_transform(X_eval)
                  pred =pr.predict(X_eval)
                  if pred >= percentiles_2:
                    Refinamiento_pred_2[j] = True
                  else:
                    Refinamiento_pred_2[j] = False
                Matriz_confusion_tree_reg = confusion_matrix(Refinamiento_test_2, Refinamiento_pred_2)
                Presicion_global_tree_reg = np.sum(Matriz_confusion_tree_reg.diagonal())/np.sum(Matriz_confusion_tree_reg)
                Presicion_SI_tree_reg = (Matriz_confusion_tree_reg[1,1])/sum(Matriz_confusion_tree_reg[1,])
                Presicion_NO_tree_reg = (Matriz_confusion_tree_reg[0,0])/sum(Matriz_confusion_tree_reg[0,])
                Puntuación_modelos_2[9,0] = Presicion_global_tree_reg
                Puntuación_modelos_2[10,0] = Presicion_SI_tree_reg
                Puntuación_modelos_2[11,0] = Presicion_NO_tree_reg
                for j in range(len(df_3['E_u'])):
                  X_eval = np.array(df_3.iloc[j,0:11])
                  pred =RFR.predict([X_eval])
                  if pred >= percentiles_2:
                   Refinamiento_pred_2[j] = True
                  else:
                   Refinamiento_pred_2[j] = False
                Matriz_confusion_tree_reg = confusion_matrix(Refinamiento_test_2, Refinamiento_pred_2)
                Presicion_global_tree_reg = np.sum(Matriz_confusion_tree_reg.diagonal())/np.sum(Matriz_confusion_tree_reg)
                Presicion_SI_tree_reg = (Matriz_confusion_tree_reg[1,1])/sum(Matriz_confusion_tree_reg[1,])
                Presicion_NO_tree_reg = (Matriz_confusion_tree_reg[0,0])/sum(Matriz_confusion_tree_reg[0,])
                Puntuación_modelos_2[3,0] = Presicion_global_tree_reg
                Puntuación_modelos_2[4,0] = Presicion_SI_tree_reg
                Puntuación_modelos_2[5,0] = Presicion_NO_tree_reg
                for j in range(len(df_3['E_u'])):
                  X_eval = np.array(df_3.iloc[j,0:11])
                  pred =RFR.predict([X_eval])
                  if pred >= percentiles_2:
                   Refinamiento_pred_2[j] = True
                  else:
                   Refinamiento_pred_2[j] = False
                Matriz_confusion_tree_reg = confusion_matrix(Refinamiento_test_2, Refinamiento_pred_2)
                Presicion_global_tree_reg = np.sum(Matriz_confusion_tree_reg.diagonal())/np.sum(Matriz_confusion_tree_reg)
                Presicion_SI_tree_reg = (Matriz_confusion_tree_reg[1,1])/sum(Matriz_confusion_tree_reg[1,])
                Presicion_NO_tree_reg = (Matriz_confusion_tree_reg[0,0])/sum(Matriz_confusion_tree_reg[0,])
                Puntuación_modelos_2[12,0] = Presicion_global_tree_reg
                Puntuación_modelos_2[13,0] = Presicion_SI_tree_reg
                Puntuación_modelos_2[14,0] = Presicion_NO_tree_reg
                for j in range(len(df_3['E_u'])):
                  X_eval = np.array(df_3.iloc[j,0:11])
                  pred =adr.predict([X_eval])
                  if pred >= percentiles_2:
                    Refinamiento_pred_2[j] = True
                  else:
                    Refinamiento_pred_2[j] = False
                Matriz_confusion_tree_reg = confusion_matrix(Refinamiento_test_2, Refinamiento_pred_2)
                Presicion_global_tree_reg = np.sum(Matriz_confusion_tree_reg.diagonal())/np.sum(Matriz_confusion_tree_reg)
                Presicion_SI_tree_reg = (Matriz_confusion_tree_reg[1,1])/sum(Matriz_confusion_tree_reg[1,])
                Presicion_NO_tree_reg = (Matriz_confusion_tree_reg[0,0])/sum(Matriz_confusion_tree_reg[0,])
                Puntuación_modelos_2[0,0] = Presicion_global_tree_reg
                Puntuación_modelos_2[1,0] = Presicion_SI_tree_reg
                Puntuación_modelos_2[2,0] = Presicion_NO_tree_reg
                df[hh +"-"+ pp+ "---" + uu] = Puntuación_modelos_2
            os.chdir(r"/mnt/c/Users/gemel/OneDrive - Universidad Técnica Federico Santa María/General - Refinamiento Adaptativo/Programas de memoria/Data_correlacion/Evaluacion_modelos/interpolacion_misma_malla")
            df.to_csv("Interpolacion"+"-" + hh +"-"+ pp +"-"+ str(TR_size*100) +"%_Ref_percent_" + str(Percent) + "%")
# Out:
# /content/drive/MyDrive/Data_Correlacion
# /content/drive/MyDrive/Data_Correlacion
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['5MMC', '1.15', '1']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['1BPI', '1.15', '1']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['2hvm', '1.15', '0.5']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['1CID', '1.15', '0.5']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['methanol', '1.15', '40']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['101M', '1.15', '0.5']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['102L', '1.15', '0.5']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['5pti', '1.15', '1']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['102L', '1.15', '0.7']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['1JJH', '1.15', '0.6']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['102L', '1.15', '0.85']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['100D', '1.15', '0.6']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['1MCY', '1.15', '0.5']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['100D', '1.15', '0.7']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['100D', '1.15', '1']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['7VW4', '1.15', '0.5']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['100D', '1.15', '1.5']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['101M', '1.15', '0.8']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['100D', '1.15', '10']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['101M', '1.15', '0.85']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['1BPI', '1.15', '0.85']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['100D', '1.15', '15']
# /content/drive/MyDrive/Data_Correlacion
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['arg', '1.15', '30']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['101M', '1.15', '0.75']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['100D', '1.15', '13']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['100D', '1.15', '13.5']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['100D', '1.15', '11']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['arg', '1.15', '25']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['arg', '1.15', '27']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['102L', '1.15', '0.8']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['methanol', '1.15', '35']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['methanol', '1.15', '37.5']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['methanol', '1.15', '33']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['methanol', '1.15', '32']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['100D', '1.15', '3']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['100D', '1.15', '4']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['100D', '1.15', '7']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['100D', '1.15', '5']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['100D', '1.15', '6']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['100D', '1.15', '8']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['arg', '1.15', '20']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['5MMC', '1.15', '1.1']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['5MMC', '1.15', '0.95']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['5MMC', '1.15', '1.05']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['5MMC', '1.15', '1.15']
# /content/drive/MyDrive/Data_Correlacion
# /content/drive/MyDrive/Data_Correlacion
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['5MMC', '1.05', '1']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['1BPI', '1.05', '1']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['2hvm', '1.05', '0.5']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['1CID', '1.05', '0.5']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['methanol', '1.05', '40']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['101M', '1.05', '0.5']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['102L', '1.05', '0.5']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['5pti', '1.05', '1']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['102L', '1.05', '0.7']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['1JJH', '1.05', '0.6']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['102L', '1.05', '0.85']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['100D', '1.05', '0.6']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['1MCY', '1.05', '0.5']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['100D', '1.05', '0.7']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['100D', '1.05', '1']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['7VW4', '1.05', '0.5']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['100D', '1.05', '1.5']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['101M', '1.05', '0.8']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['100D', '1.05', '10']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['101M', '1.05', '0.85']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['1BPI', '1.05', '0.85']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['100D', '1.05', '15']
# /content/drive/MyDrive/Data_Correlacion
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['arg', '1.05', '30']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['101M', '1.05', '0.75']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['100D', '1.05', '13']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['100D', '1.05', '13.5']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['100D', '1.05', '11']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['arg', '1.05', '25']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['arg', '1.05', '27']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['102L', '1.05', '0.8']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['methanol', '1.05', '35']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['methanol', '1.05', '37.5']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['methanol', '1.05', '33']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['methanol', '1.05', '32']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['100D', '1.05', '3']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['100D', '1.05', '4']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['100D', '1.05', '7']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['100D', '1.05', '5']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['100D', '1.05', '6']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['100D', '1.05', '8']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['arg', '1.05', '20']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['5MMC', '1.05', '1.1']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['5MMC', '1.05', '0.95']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['5MMC', '1.05', '1.05']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['5MMC', '1.05', '1.15']
# Streaming output truncated to the last 5000 lines.
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# ...
# /content/drive/MyDrive/Data_Correlacion
# 101M ['5MMC', '0.5', '1.05']
# /content/drive/MyDrive/Data_Correlacion
# 101M ['5MMC', '0.5', '1.15']
# /content/drive/MyDrive/Data_Correlacion
# /content/drive/MyDrive/Data_Correlacion
# /content/drive/MyDrive/Data_Correlacion
# methanol ['5MMC', '40', '1']
# /content/drive/MyDrive/Data_Correlacion
# methanol ['1BPI', '40', '1']
# /content/drive/MyDrive/Data_Correlacion
# methanol ['2hvm', '40', '0.5']
# /content/drive/MyDrive/Data_Correlacion
# methanol ['1CID', '40', '0.5']
# /content/drive/MyDrive/Data_Correlacion
# methanol ['methanol', '40', '40']
# /content/drive/MyDrive/Data_Correlacion
# methanol ['101M', '40', '0.5']
# /content/drive/MyDrive/Data_Correlacion
# methanol ['102L', '40', '0.5']
# /content/drive/MyDrive/Data_Correlacion
# methanol ['5pti', '40', '1']
# /content/drive/MyDrive/Data_Correlacion
# methanol ['102L', '40', '0.7']
# /content/drive/MyDrive/Data_Correlacion
# methanol ['1JJH', '40', '0.6']
# /content/drive/MyDrive/Data_Correlacion
# methanol ['102L', '40', '0.85']
# /content/drive/MyDrive/Data_Correlacion
# methanol ['100D', '40', '0.6']
# /content/drive/MyDrive/Data_Correlacion
# methanol ['1MCY', '40', '0.5']
# /content/drive/MyDrive/Data_Correlacion
# methanol ['100D', '40', '0.7']
# /content/drive/MyDrive/Data_Correlacion
# methanol ['100D', '40', '1']
# /content/drive/MyDrive/Data_Correlacion
# methanol ['7VW4', '40', '0.5']
# /content/drive/MyDrive/Data_Correlacion
# methanol ['100D', '40', '1.5']
# /content/drive/MyDrive/Data_Correlacion
# methanol ['101M', '40', '0.8']
# /content/drive/MyDrive/Data_Correlacion
# methanol ['100D', '40', '10']
# /content/drive/MyDrive/Data_Correlacion
# methanol ['101M', '40', '0.85']
# /content/drive/MyDrive/Data_Correlacion
# methanol ['1BPI', '40', '0.85']
# /content/drive/MyDrive/Data_Correlacion
# methanol ['100D', '40', '15']
# /content/drive/MyDrive/Data_Correlacion
# /content/drive/MyDrive/Data_Correlacion
# methanol ['arg', '40', '30']
# /content/drive/MyDrive/Data_Correlacion
# methanol ['101M', '40', '0.75']
# /content/drive/MyDrive/Data_Correlacion
# methanol ['100D', '40', '13']
# /content/drive/MyDrive/Data_Correlacion
# methanol ['100D', '40', '13.5']
# /content/drive/MyDrive/Data_Correlacion
# methanol ['100D', '40', '11']
# /content/drive/MyDrive/Data_Correlacion
# methanol ['arg', '40', '25']
# /content/drive/MyDrive/Data_Correlacion
# methanol ['arg', '40', '27']
# /content/drive/MyDrive/Data_Correlacion
# methanol ['102L', '40', '0.8']
# /content/drive/MyDrive/Data_Correlacion
# methanol ['methanol', '40', '35']
# /content/drive/MyDrive/Data_Correlacion
# methanol ['methanol', '40', '37.5']
# /content/drive/MyDrive/Data_Correlacion
# methanol ['methanol', '40', '33']
# /content/drive/MyDrive/Data_Correlacion
# methanol ['methanol', '40', '32']
# /content/drive/MyDrive/Data_Correlacion
# methanol ['100D', '40', '3']
# /content/drive/MyDrive/Data_Correlacion
# methanol ['100D', '40', '4']
# /content/drive/MyDrive/Data_Correlacion
# methanol ['100D', '40', '7']
# /content/drive/MyDrive/Data_Correlacion
# methanol ['100D', '40', '5']
# /content/drive/MyDrive/Data_Correlacion
# methanol ['100D', '40', '6']
# /content/drive/MyDrive/Data_Correlacion
# methanol ['100D', '40', '8']
# /content/drive/MyDrive/Data_Correlacion
# methanol ['arg', '40', '20']
# /content/drive/MyDrive/Data_Correlacion
# methanol ['5MMC', '40', '1.1']
# /content/drive/MyDrive/Data_Correlacion
# methanol ['5MMC', '40', '0.95']
# /content/drive/MyDrive/Data_Correlacion
# methanol ['5MMC', '40', '1.05']
# /content/drive/MyDrive/Data_Correlacion
# methanol ['5MMC', '40', '1.15']
# /content/drive/MyDrive/Data_Correlacion
# /content/drive/MyDrive/Data_Correlacion
# /content/drive/MyDrive/Data_Correlacion
# 1CID ['5MMC', '0.5', '1']
# /content/drive/MyDrive/Data_Correlacion
# 1CID ['1BPI', '0.5', '1']
# /content/drive/MyDrive/Data_Correlacion
# 1CID ['2hvm', '0.5', '0.5']
# /content/drive/MyDrive/Data_Correlacion
# 1CID ['1CID', '0.5', '0.5']
# /content/drive/MyDrive/Data_Correlacion
# 1CID ['methanol', '0.5', '40']
# /content/drive/MyDrive/Data_Correlacion
# 1CID ['101M', '0.5', '0.5']
# /content/drive/MyDrive/Data_Correlacion
# 1CID ['102L', '0.5', '0.5']
# /content/drive/MyDrive/Data_Correlacion
# 1CID ['5pti', '0.5', '1']
# /content/drive/MyDrive/Data_Correlacion
# 1CID ['102L', '0.5', '0.7']
# /content/drive/MyDrive/Data_Correlacion
# 1CID ['1JJH', '0.5', '0.6']
# /content/drive/MyDrive/Data_Correlacion
# 1CID ['102L', '0.5', '0.85']
# /content/drive/MyDrive/Data_Correlacion
# 1CID ['100D', '0.5', '0.6']
# /content/drive/MyDrive/Data_Correlacion
# 1CID ['1MCY', '0.5', '0.5']
# /content/drive/MyDrive/Data_Correlacion
# 1CID ['100D', '0.5', '0.7']
# /content/drive/MyDrive/Data_Correlacion
# 1CID ['100D', '0.5', '1']
# /content/drive/MyDrive/Data_Correlacion
# 1CID ['7VW4', '0.5', '0.5']
# /content/drive/MyDrive/Data_Correlacion
# 1CID ['100D', '0.5', '1.5']
# /content/drive/MyDrive/Data_Correlacion
# 1CID ['101M', '0.5', '0.8']
# /content/drive/MyDrive/Data_Correlacion
# 1CID ['100D', '0.5', '10']
# /content/drive/MyDrive/Data_Correlacion
# 1CID ['101M', '0.5', '0.85']
# /content/drive/MyDrive/Data_Correlacion
# 1CID ['1BPI', '0.5', '0.85']
# /content/drive/MyDrive/Data_Correlacion
# 1CID ['100D', '0.5', '15']
# /content/drive/MyDrive/Data_Correlacion
# /content/drive/MyDrive/Data_Correlacion
# 1CID ['arg', '0.5', '30']
# /content/drive/MyDrive/Data_Correlacion
# 1CID ['101M', '0.5', '0.75']
# /content/drive/MyDrive/Data_Correlacion
# 1CID ['100D', '0.5', '13']
# /content/drive/MyDrive/Data_Correlacion
# 1CID ['100D', '0.5', '13.5']
# /content/drive/MyDrive/Data_Correlacion
# 1CID ['100D', '0.5', '11']
# /content/drive/MyDrive/Data_Correlacion
# 1CID ['arg', '0.5', '25']
# /content/drive/MyDrive/Data_Correlacion
# 1CID ['arg', '0.5', '27']
# /content/drive/MyDrive/Data_Correlacion
# 1CID ['102L', '0.5', '0.8']
# /content/drive/MyDrive/Data_Correlacion
# 1CID ['methanol', '0.5', '35']
# /content/drive/MyDrive/Data_Correlacion
# 1CID ['methanol', '0.5', '37.5']
# /content/drive/MyDrive/Data_Correlacion
# 1CID ['methanol', '0.5', '33']
# /content/drive/MyDrive/Data_Correlacion
# 1CID ['methanol', '0.5', '32']
# /content/drive/MyDrive/Data_Correlacion
# 1CID ['100D', '0.5', '3']
# /content/drive/MyDrive/Data_Correlacion
# 1CID ['100D', '0.5', '4']
# /content/drive/MyDrive/Data_Correlacion
# 1CID ['100D', '0.5', '7']
# /content/drive/MyDrive/Data_Correlacion
# 1CID ['100D', '0.5', '5']
# /content/drive/MyDrive/Data_Correlacion
# 1CID ['100D', '0.5', '6']
# /content/drive/MyDrive/Data_Correlacion
# 1CID ['100D', '0.5', '8']
# /content/drive/MyDrive/Data_Correlacion
# 1CID ['arg', '0.5', '20']
# /content/drive/MyDrive/Data_Correlacion
# 1CID ['5MMC', '0.5', '1.1']
# /content/drive/MyDrive/Data_Correlacion
# 1CID ['5MMC', '0.5', '0.95']
# /content/drive/MyDrive/Data_Correlacion
# 1CID ['5MMC', '0.5', '1.05']
# /content/drive/MyDrive/Data_Correlacion
# 1CID ['5MMC', '0.5', '1.15']
# /content/drive/MyDrive/Data_Correlacion
# /content/drive/MyDrive/Data_Correlacion
# /content/drive/MyDrive/Data_Correlacion
# 2hvm ['5MMC', '0.5', '1']
# /content/drive/MyDrive/Data_Correlacion
# 2hvm ['1BPI', '0.5', '1']
# /content/drive/MyDrive/Data_Correlacion
# 2hvm ['2hvm', '0.5', '0.5']
# /content/drive/MyDrive/Data_Correlacion
# 2hvm ['1CID', '0.5', '0.5']
# /content/drive/MyDrive/Data_Correlacion
# 2hvm ['methanol', '0.5', '40']
# /content/drive/MyDrive/Data_Correlacion
# 2hvm ['101M', '0.5', '0.5']
# /content/drive/MyDrive/Data_Correlacion
# 2hvm ['102L', '0.5', '0.5']
# /content/drive/MyDrive/Data_Correlacion
# 2hvm ['5pti', '0.5', '1']
# /content/drive/MyDrive/Data_Correlacion
# 2hvm ['102L', '0.5', '0.7']
# /content/drive/MyDrive/Data_Correlacion
# 2hvm ['1JJH', '0.5', '0.6']
# /content/drive/MyDrive/Data_Correlacion
# 2hvm ['102L', '0.5', '0.85']
# /content/drive/MyDrive/Data_Correlacion
# 2hvm ['100D', '0.5', '0.6']
# /content/drive/MyDrive/Data_Correlacion
# 2hvm ['1MCY', '0.5', '0.5']
# /content/drive/MyDrive/Data_Correlacion
# 2hvm ['100D', '0.5', '0.7']
# /content/drive/MyDrive/Data_Correlacion
# 2hvm ['100D', '0.5', '1']
# /content/drive/MyDrive/Data_Correlacion
# 2hvm ['7VW4', '0.5', '0.5']
# /content/drive/MyDrive/Data_Correlacion
# 2hvm ['100D', '0.5', '1.5']
# /content/drive/MyDrive/Data_Correlacion
# 2hvm ['101M', '0.5', '0.8']
# /content/drive/MyDrive/Data_Correlacion
# 2hvm ['100D', '0.5', '10']
# /content/drive/MyDrive/Data_Correlacion
# 2hvm ['101M', '0.5', '0.85']
# /content/drive/MyDrive/Data_Correlacion
# 2hvm ['1BPI', '0.5', '0.85']
# /content/drive/MyDrive/Data_Correlacion
# 2hvm ['100D', '0.5', '15']
# /content/drive/MyDrive/Data_Correlacion
# /content/drive/MyDrive/Data_Correlacion
# 2hvm ['arg', '0.5', '30']
# /content/drive/MyDrive/Data_Correlacion
# 2hvm ['101M', '0.5', '0.75']
# /content/drive/MyDrive/Data_Correlacion
# 2hvm ['100D', '0.5', '13']
# /content/drive/MyDrive/Data_Correlacion
# 2hvm ['100D', '0.5', '13.5']
# /content/drive/MyDrive/Data_Correlacion
# 2hvm ['100D', '0.5', '11']
# /content/drive/MyDrive/Data_Correlacion
# 2hvm ['arg', '0.5', '25']
# /content/drive/MyDrive/Data_Correlacion
# 2hvm ['arg', '0.5', '27']
# /content/drive/MyDrive/Data_Correlacion
# 2hvm ['102L', '0.5', '0.8']
# /content/drive/MyDrive/Data_Correlacion
# 2hvm ['methanol', '0.5', '35']
# /content/drive/MyDrive/Data_Correlacion
# 2hvm ['methanol', '0.5', '37.5']
# /content/drive/MyDrive/Data_Correlacion
# 2hvm ['methanol', '0.5', '33']
# /content/drive/MyDrive/Data_Correlacion
# 2hvm ['methanol', '0.5', '32']
# /content/drive/MyDrive/Data_Correlacion
# 2hvm ['100D', '0.5', '3']
# /content/drive/MyDrive/Data_Correlacion
# 2hvm ['100D', '0.5', '4']
# /content/drive/MyDrive/Data_Correlacion
# 2hvm ['100D', '0.5', '7']
# /content/drive/MyDrive/Data_Correlacion
# 2hvm ['100D', '0.5', '5']
# /content/drive/MyDrive/Data_Correlacion
# 2hvm ['100D', '0.5', '6']
# /content/drive/MyDrive/Data_Correlacion
# 2hvm ['100D', '0.5', '8']
# /content/drive/MyDrive/Data_Correlacion
# 2hvm ['arg', '0.5', '20']
# /content/drive/MyDrive/Data_Correlacion
# 2hvm ['5MMC', '0.5', '1.1']
# /content/drive/MyDrive/Data_Correlacion
# 2hvm ['5MMC', '0.5', '0.95']
# /content/drive/MyDrive/Data_Correlacion
# 2hvm ['5MMC', '0.5', '1.05']
# /content/drive/MyDrive/Data_Correlacion
# 2hvm ['5MMC', '0.5', '1.15']
# /content/drive/MyDrive/Data_Correlacion
# /content/drive/MyDrive/Data_Correlacion
# /content/drive/MyDrive/Data_Correlacion
# 1BPI ['5MMC', '1', '1']
# /content/drive/MyDrive/Data_Correlacion
# 1BPI ['1BPI', '1', '1']
# /content/drive/MyDrive/Data_Correlacion
# 1BPI ['2hvm', '1', '0.5']
# /content/drive/MyDrive/Data_Correlacion
# 1BPI ['1CID', '1', '0.5']
# /content/drive/MyDrive/Data_Correlacion
# 1BPI ['methanol', '1', '40']
# /content/drive/MyDrive/Data_Correlacion
# 1BPI ['101M', '1', '0.5']
# /content/drive/MyDrive/Data_Correlacion
# 1BPI ['102L', '1', '0.5']
# /content/drive/MyDrive/Data_Correlacion
# 1BPI ['5pti', '1', '1']
# /content/drive/MyDrive/Data_Correlacion
# 1BPI ['102L', '1', '0.7']
# /content/drive/MyDrive/Data_Correlacion
# 1BPI ['1JJH', '1', '0.6']
# /content/drive/MyDrive/Data_Correlacion
# 1BPI ['102L', '1', '0.85']
# /content/drive/MyDrive/Data_Correlacion
# 1BPI ['100D', '1', '0.6']
# /content/drive/MyDrive/Data_Correlacion
# 1BPI ['1MCY', '1', '0.5']
# /content/drive/MyDrive/Data_Correlacion
# 1BPI ['100D', '1', '0.7']
# /content/drive/MyDrive/Data_Correlacion
# 1BPI ['100D', '1', '1']
# /content/drive/MyDrive/Data_Correlacion
# 1BPI ['7VW4', '1', '0.5']
# /content/drive/MyDrive/Data_Correlacion
# 1BPI ['100D', '1', '1.5']
# /content/drive/MyDrive/Data_Correlacion
# 1BPI ['101M', '1', '0.8']
# /content/drive/MyDrive/Data_Correlacion
# 1BPI ['100D', '1', '10']
# /content/drive/MyDrive/Data_Correlacion
# 1BPI ['101M', '1', '0.85']
# /content/drive/MyDrive/Data_Correlacion
# 1BPI ['1BPI', '1', '0.85']
# /content/drive/MyDrive/Data_Correlacion
# 1BPI ['100D', '1', '15']
# /content/drive/MyDrive/Data_Correlacion
# /content/drive/MyDrive/Data_Correlacion
# 1BPI ['arg', '1', '30']
# /content/drive/MyDrive/Data_Correlacion
# 1BPI ['101M', '1', '0.75']
# /content/drive/MyDrive/Data_Correlacion
# 1BPI ['100D', '1', '13']
# /content/drive/MyDrive/Data_Correlacion
# 1BPI ['100D', '1', '13.5']
# /content/drive/MyDrive/Data_Correlacion
# 1BPI ['100D', '1', '11']
# /content/drive/MyDrive/Data_Correlacion
# 1BPI ['arg', '1', '25']
# /content/drive/MyDrive/Data_Correlacion
# 1BPI ['arg', '1', '27']
# /content/drive/MyDrive/Data_Correlacion
# 1BPI ['102L', '1', '0.8']
# /content/drive/MyDrive/Data_Correlacion
# 1BPI ['methanol', '1', '35']
# /content/drive/MyDrive/Data_Correlacion
# 1BPI ['methanol', '1', '37.5']
# /content/drive/MyDrive/Data_Correlacion
# 1BPI ['methanol', '1', '33']
# /content/drive/MyDrive/Data_Correlacion
# 1BPI ['methanol', '1', '32']
# /content/drive/MyDrive/Data_Correlacion
# 1BPI ['100D', '1', '3']
# /content/drive/MyDrive/Data_Correlacion
# 1BPI ['100D', '1', '4']
# /content/drive/MyDrive/Data_Correlacion
# 1BPI ['100D', '1', '7']
# /content/drive/MyDrive/Data_Correlacion
# 1BPI ['100D', '1', '5']
# /content/drive/MyDrive/Data_Correlacion
# 1BPI ['100D', '1', '6']
# /content/drive/MyDrive/Data_Correlacion
# 1BPI ['100D', '1', '8']
# /content/drive/MyDrive/Data_Correlacion
# 1BPI ['arg', '1', '20']
# /content/drive/MyDrive/Data_Correlacion
# 1BPI ['5MMC', '1', '1.1']
# /content/drive/MyDrive/Data_Correlacion
# 1BPI ['5MMC', '1', '0.95']
# /content/drive/MyDrive/Data_Correlacion
# 1BPI ['5MMC', '1', '1.05']
# /content/drive/MyDrive/Data_Correlacion
# 1BPI ['5MMC', '1', '1.15']
# /content/drive/MyDrive/Data_Correlacion
# /content/drive/MyDrive/Data_Correlacion
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['5MMC', '1', '1']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['1BPI', '1', '1']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['2hvm', '1', '0.5']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['1CID', '1', '0.5']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['methanol', '1', '40']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['101M', '1', '0.5']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['102L', '1', '0.5']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['5pti', '1', '1']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['102L', '1', '0.7']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['1JJH', '1', '0.6']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['102L', '1', '0.85']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['100D', '1', '0.6']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['1MCY', '1', '0.5']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['100D', '1', '0.7']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['100D', '1', '1']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['7VW4', '1', '0.5']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['100D', '1', '1.5']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['101M', '1', '0.8']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['100D', '1', '10']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['101M', '1', '0.85']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['1BPI', '1', '0.85']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['100D', '1', '15']
# /content/drive/MyDrive/Data_Correlacion
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['arg', '1', '30']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['101M', '1', '0.75']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['100D', '1', '13']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['100D', '1', '13.5']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['100D', '1', '11']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['arg', '1', '25']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['arg', '1', '27']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['102L', '1', '0.8']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['methanol', '1', '35']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['methanol', '1', '37.5']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['methanol', '1', '33']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['methanol', '1', '32']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['100D', '1', '3']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['100D', '1', '4']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['100D', '1', '7']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['100D', '1', '5']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['100D', '1', '6']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['100D', '1', '8']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['arg', '1', '20']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['5MMC', '1', '1.1']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['5MMC', '1', '0.95']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['5MMC', '1', '1.05']
# /content/drive/MyDrive/Data_Correlacion
# 5MMC ['5MMC', '1', '1.15']
# /content/drive/MyDrive/Data_Correlacion
